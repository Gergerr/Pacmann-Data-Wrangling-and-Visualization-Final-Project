# %% [markdown]
# ## 00. Load the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path= 'Dataset Marketing.csv'
data= pd.read_csv(file_path)

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
data.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# It seems there are 313 missing values in minimum payments. We will see the distribution first, then we'll decide later what to do with the missing values.

# %% [markdown]
# ## 10. Data Cleaning

# %% [markdown]
# ## 11. Handling Missing Values

# %%
# Plot histogram of 'MINIMUM_PAYMENTS'
plt.figure(figsize=(18, 6))
data['MINIMUM_PAYMENTS'].hist(bins=50)
plt.title('Distribution of MINIMUM_PAYMENTS')
plt.xlabel('Minimum Payments')
plt.ylabel('Frequency')
plt.show()

# %%
data['MINIMUM_PAYMENTS'].describe()
# Out:
# count     8637.000000
# mean       864.206542
# std       2372.446607
# min          0.019163
# 25%        169.123707
# 50%        312.343947
# 75%        825.485459
# max      76406.207520
# Name: MINIMUM_PAYMENTS, dtype: float64

# %% [markdown]
# It seems that there are an outlier, and the data is skewed. Therefore I'll choose median to fill the missing values.

# %%
data['MINIMUM_PAYMENTS'].fillna(data['MINIMUM_PAYMENTS'].median(), inplace= True)
data.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        1
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# It seems that there are 1 more missing values in `CREDIT LIMIT`, I'll fill it with the median too

# %%
data['CREDIT_LIMIT'].fillna(data['CREDIT_LIMIT'].median(), inplace= True)
data.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %% [markdown]
# # 12. Correcting Data Types

# %%
data.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %% [markdown]
# It seems that `CUST_ID` should be `STR`

# %%
data['CUST_ID']= data['CUST_ID'].astype(str)

# %% [markdown]
# Here we have fixed it. Lets move on to our next exploratory data analysis

# %%
data.dtypes
# Out:
# CUST_ID                              object
# BALANCE                             float64
# BALANCE_FREQUENCY                   float64
# PURCHASES                           float64
# ONEOFF_PURCHASES                    float64
# INSTALLMENTS_PURCHASES              float64
# CASH_ADVANCE                        float64
# PURCHASES_FREQUENCY                 float64
# ONEOFF_PURCHASES_FREQUENCY          float64
# PURCHASES_INSTALLMENTS_FREQUENCY    float64
# CASH_ADVANCE_FREQUENCY              float64
# CASH_ADVANCE_TRX                      int64
# PURCHASES_TRX                         int64
# CREDIT_LIMIT                        float64
# PAYMENTS                            float64
# MINIMUM_PAYMENTS                    float64
# PRC_FULL_PAYMENT                    float64
# TENURE                                int64
# dtype: object

# %% [markdown]
# # 20. Basic Data Exploration

# %%
# Checking the distribution of key metrics
KEY_METRICS= ['BALANCE', 'PURCHASES', 'CASH_ADVANCE', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'TENURE']
for metric in KEY_METRICS:
    plt.figure(figsize= (18, 6))
    sns.histplot(data[metric], kde= True)
    plt.title(f'Distribution of {metric}')
    plt.xlabel(f'{metric}')
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# # 21. Checking Outlier

# %%
# Boxplot to check for outliers in Metrics
for metric in KEY_METRICS:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=data[metric])
    plt.title(f'Box Plot of {metric}')
    plt.show()

# %% [markdown]
# # 22. Categorizing a few metrics

# %%
# I was considering to use quantiles for this.
balance_quantiles = data['BALANCE'].quantile([0.33, 0.66])
credit_limit_quantiles = data['CREDIT_LIMIT'].quantile([0.33, 0.66])

print(f"Balance quantiles at 33% and 66%: \n{balance_quantiles}")
print(f"\n====\nCredit limit quantiles at 33% and 66%: \n{credit_limit_quantiles}")
# Out:
# Balance quantiles at 33% and 66%:
# 0.33     269.988522
# 0.66    1478.072900
# Name: BALANCE, dtype: float64
#
# ====
# Credit limit quantiles at 33% and 66%:
# 0.33    2000.0
# 0.66    5000.0
# Name: CREDIT_LIMIT, dtype: float64

# %% [markdown]
# However, after seeing the quantiles, I'll check the descriptive statistics of each data.

# %%
data[['BALANCE', 'CREDIT_LIMIT']].describe()
# Out:
#             BALANCE  CREDIT_LIMIT
# count   8950.000000   8950.000000
# mean    1564.474828   4494.282473
# std     2081.531879   3638.646702
# min        0.000000     50.000000
# 25%      128.281915   1600.000000
# 50%      873.385231   3000.000000
# 75%     2054.140036   6500.000000
# max    19043.138560  30000.000000

# %% [markdown]
# Okay, it seems that using quantile is kinda bad!
# After having a thoughtful guess.
#
# Basically, what this does, is setting **Balance** and **Credit Limit** to a categories.
# |Balance|Category|
# |:---:|:---:|
# |<2500| Green |
# |<7500| Gold |
# |>=7500| Platinum|
#
# Then, for Credit Limit categorization:
#
# |Credit Limit|Category|
# |:---:|:---:|
# |<6500| Green |
# |<13000| Gold |
# |>=13000| Platinum|

# %%
# Categorize 'BALANCE'
data['BALANCE_CATEGORY'] = pd.cut(data['BALANCE'],
                                  bins=[-float('inf'), 2500, 7500, float('inf')],
                                  labels=['Green', 'Gold', 'Platinum'])

# Categorize 'CREDIT_LIMIT'
data['CREDIT_LIMIT_CATEGORY'] = pd.cut(data['CREDIT_LIMIT'],
                                       bins=[-float('inf'), 6500, 13000, float('inf')],
                                       labels=['Green', 'Gold', 'Platinum'])

# %%
balance_credit_colorpalette= ['#097969', '#FFD700', '#E5E4E2']
# Plotting the distribution of Balance Categories
plt.figure(figsize=(10, 6))
balance_bar= sns.countplot(x='BALANCE_CATEGORY', data=data, palette= balance_credit_colorpalette)
plt.title('Distribution of Balance Categories')
plt.xlabel('Balance Categories')
plt.ylabel('Number of Customers')

# This to shows the number above bar
for p in balance_bar.patches:
    balance_bar.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points')

plt.show()
# Out:
# /var/folders/jc/46_slfdn1kqdqvhq8h39xbk80000gn/T/ipykernel_6873/4291818742.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   balance_bar= sns.countplot(x='BALANCE_CATEGORY', data=data, palette= balance_credit_colorpalette)

# %% [markdown]
# Now, we will check the average and median of balance by each category.

# %%
print("The mean of balance in each category: \n", data.groupby(by= 'BALANCE_CATEGORY')['BALANCE'].mean())
print("\nThe median of balance in each category: \n", data.groupby(by= 'BALANCE_CATEGORY')['BALANCE'].max())
# Out:
# The mean of balance in each category:
#  BALANCE_CATEGORY
# Green        704.096328
# Gold        4208.352486
# Platinum    9683.769234
# Name: BALANCE, dtype: float64
#
# The median of balance in each category:
#  BALANCE_CATEGORY
# Green        2499.228939
# Gold         7499.658084
# Platinum    19043.138560
# Name: BALANCE, dtype: float64
# /var/folders/jc/46_slfdn1kqdqvhq8h39xbk80000gn/T/ipykernel_6873/1288976905.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print("The mean of balance in each category: \n", data.groupby(by= 'BALANCE_CATEGORY')['BALANCE'].mean())
# ...

# %%
# Plotting the distribution of Credit Limit Categories
plt.figure(figsize=(10, 6))
credit_bar= sns.countplot(x='CREDIT_LIMIT_CATEGORY', data=data, palette= balance_credit_colorpalette)
plt.title('Distribution of Credit Limit Categories')
plt.xlabel('Credit Limit Categories')
plt.ylabel('Number of Customers')

for p in credit_bar.patches:
    credit_bar.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=10, color='black', xytext=(0, 5), textcoords='offset points')

plt.show()
# Out:
# /var/folders/jc/46_slfdn1kqdqvhq8h39xbk80000gn/T/ipykernel_6873/2792351193.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   credit_bar= sns.countplot(x='CREDIT_LIMIT_CATEGORY', data=data, palette= balance_credit_colorpalette)

# %%
print("The mean of credit limit in each category: \n", data.groupby(by= 'CREDIT_LIMIT_CATEGORY')['CREDIT_LIMIT'].mean())
print("\nThe median of credit limit in each category: \n", data.groupby(by= 'CREDIT_LIMIT_CATEGORY')['CREDIT_LIMIT'].max())
# Out:
# The mean of credit limit in each category:
#  CREDIT_LIMIT_CATEGORY
# Green        2874.959328
# Gold         8991.030063
# Platinum    16251.630435
# Name: CREDIT_LIMIT, dtype: float64
#
# The median of credit limit in each category:
#  CREDIT_LIMIT_CATEGORY
# Green        6500.0
# Gold        13000.0
# Platinum    30000.0
# Name: CREDIT_LIMIT, dtype: float64
# /var/folders/jc/46_slfdn1kqdqvhq8h39xbk80000gn/T/ipykernel_6873/3861304554.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print("The mean of credit limit in each category: \n", data.groupby(by= 'CREDIT_LIMIT_CATEGORY')['CREDIT_LIMIT'].mean())
# ...

# %% [markdown]
# # 30. Exploratory Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
numerical_data= data.drop('CUST_ID', axis= 1)
corre = numerical_data.corr()

# Generate a heatmap to visualize the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(corre, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 6
#       4 # Compute the correlation matrix
#       5 numerical_data= data.drop('CUST_ID', axis= 1)
# ----> 6 corre = numerical_data.corr()
#       8 # Generate a heatmap to visualize the correlation matrix
#       9 plt.figure(figsize=(12, 10))
#
# File ~/miniconda3/envs/testbaru/lib/python3.10/site-packages/pandas/core/frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/miniconda3/envs/testbaru/lib/python3.10/site-packages/pandas/core/frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
# ...

# %% [markdown]
# # 31. Answering the first objective
# What is our first objective?
#
# 1. Identifying High-Risk Customers: Those who frequently take cash-advance or have high balance.

# %%
data['HIGH_RISK_CASH_ADVANCE'] = pd.cut(data['CASH_ADVANCE_FREQUENCY'], bins=[0, 0.1, 0.5, data['CASH_ADVANCE_FREQUENCY'].max()], labels=['Low', 'Medium', 'High'])
data['HIGH_RISK_BALANCE'] = pd.cut(data['BALANCE'], bins=[0, 1000, 3000, data['BALANCE'].max()], labels=['Low', 'Medium', 'High'])

# Grouping data to see average cash advance and balance in each category
risk_group = data.groupby(['HIGH_RISK_CASH_ADVANCE', 'HIGH_RISK_BALANCE']).agg({
    'CASH_ADVANCE': 'mean',
    'BALANCE': 'mean',
    'CREDIT_LIMIT': 'mean',
    'PAYMENTS': 'mean'
}).reset_index()

risk_group.head()
# Out:
# /var/folders/jc/46_slfdn1kqdqvhq8h39xbk80000gn/T/ipykernel_6873/2302402200.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   risk_group = data.groupby(['HIGH_RISK_CASH_ADVANCE', 'HIGH_RISK_BALANCE']).agg({
#   HIGH_RISK_CASH_ADVANCE HIGH_RISK_BALANCE  CASH_ADVANCE      BALANCE  \
# 0                    Low               Low    691.427932   384.620110
# 1                    Low            Medium    696.783865  1735.082788
# 2                    Low              High   1536.770783  5144.607378
# 3                 Medium               Low   1217.265124   512.796255
# 4                 Medium            Medium   1695.153404  1799.516627
#
#    CREDIT_LIMIT     PAYMENTS
# 0   3327.405905  1554.594248
# 1   3342.414530  1340.980082
# 2   8294.753086  3215.181158
# 3   2615.405405  1441.781722
# ...

# %% [markdown]
# The reason I chose this is to categorize and analyze customer data based on two key indicators of financial risk: cash advance frequency and account balance. The intention is to identify patterns or clusters of behavior that could signify higher or lower financial risk.
#
# Why?
# * Cash Advance Frequency: Frequent cash advances can indicate reliance on credit for daily liquidity, which may be a sign of underlying financial instability or distress. By categorizing this frequency into 'Low', 'Medium', and 'High', we can differentiate between occasional and potentially risky habitual reliance on cash advances.
#
# * Balance: High balances, especially those close to or at the credit limit, can also signal potential financial stress or risk. Segmenting balances into categories helps in identifying customers who may be over-leveraged.

# %%
# Correctly creating a pivot table for the heatmap
risk_heatmap_data = data.pivot_table(index='HIGH_RISK_CASH_ADVANCE', columns='HIGH_RISK_BALANCE', values='BALANCE', aggfunc='mean')

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(risk_heatmap_data, annot=True, fmt=".0f", cmap='Reds', cbar_kws={'label': 'Average Balance'})
plt.title('Risk Levels by Cash Advance Frequency and Balance')
plt.xlabel('Balance Risk Level')
plt.ylabel('Cash Advance Risk Level')
plt.show()

# %%
# Normalize each component to be between 0 and 1
data['BALANCE_NORM'] = (data['BALANCE'] - data['BALANCE'].min()) / (data['BALANCE'].max() - data['BALANCE'].min())
data['CASH_ADVANCE_FREQ_NORM'] = (data['CASH_ADVANCE_FREQUENCY'] - data['CASH_ADVANCE_FREQUENCY'].min()) / (data['CASH_ADVANCE_FREQUENCY'].max() - data['CASH_ADVANCE_FREQUENCY'].min())
data['FULL_PAYMENT_NORM'] = (data['PRC_FULL_PAYMENT'] - data['PRC_FULL_PAYMENT'].min()) / (data['PRC_FULL_PAYMENT'].max() - data['PRC_FULL_PAYMENT'].min())

# Calculate the risk score by adding the normalized values, considering to invert the full payment norm to reflect risk properly (higher scores indicate lower payments)
data['RISK_SCORE'] = (
    0.5 * data['BALANCE_NORM'] +
    0.3 * data['CASH_ADVANCE_FREQ_NORM'] +
    0.2 * (1 - data['FULL_PAYMENT_NORM'])  # Inverting the full payment contribution to risk
)

# Ensuring the risk score does not go below zero
data['RISK_SCORE'] = data['RISK_SCORE'].clip(lower=0)

# %%
# Assuming weights for each risk factor based on hypothetical business insights
# data['RISK_SCORE'] = (
#     0.5 * pd.cut(data['BALANCE'], bins=3, labels=False) +
#     0.3 * pd.cut(data['CASH_ADVANCE_FREQUENCY'], bins=3, labels=False) +
#     0.2 * (1 - pd.cut(data['PRC_FULL_PAYMENT'], bins=3, labels=False))
# )

# Visualizing the distribution of the risk score
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(data['RISK_SCORE'], bins=10, kde=False)
plt.title('Distribution of Composite Risk Score')
plt.xlabel('Risk Score')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Example: Chi-Square Test between risk category and a categorical outcome like delinquency status
from scipy.stats import chi2_contingency

# Hypothetical coding of delinquency status
data['DELINQUENCY_STATUS'] = (data['BALANCE'] > 3000).astype(int)  # Simplified assumption

contingency_table = pd.crosstab(data['BALANCE_CATEGORY'], data['DELINQUENCY_STATUS'])
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-square test result -- chi2: {chi2}, p-value: {p}")
# Out:
# Chi-square test result -- chi2: 6737.230369751323, p-value: 0.0

# %%
# Grouping data by 'BALANCE_CATEGORY' and calculating average values of other risk factors
grouped_data = data.groupby('BALANCE_CATEGORY').agg({
    'CASH_ADVANCE_FREQUENCY': 'mean',
    'PRC_FULL_PAYMENT': 'mean',
    'CREDIT_LIMIT': 'mean',
    'PAYMENTS': 'mean'
}).reset_index()

print(grouped_data)
# Out:
#   BALANCE_CATEGORY  CASH_ADVANCE_FREQUENCY  PRC_FULL_PAYMENT  CREDIT_LIMIT  \
# 0            Green                0.095038          0.189737   3628.140204
# 1             Gold                0.282246          0.016471   7115.931455
# 2         Platinum                0.339668          0.007352  12959.192825
#
#       PAYMENTS
# 0  1351.735378
# 1  2882.673107
# 2  5496.583321
# /var/folders/jc/46_slfdn1kqdqvhq8h39xbk80000gn/T/ipykernel_37398/2445009755.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby('BALANCE_CATEGORY').agg({

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar plot for each factor by balance category
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

sns.barplot(x='BALANCE_CATEGORY', y='CASH_ADVANCE_FREQUENCY', data=grouped_data, ax=axs[0, 0])
axs[0, 0].set_title('Average Cash Advance Frequency by Balance Category')

sns.barplot(x='BALANCE_CATEGORY', y='PRC_FULL_PAYMENT', data=grouped_data, ax=axs[0, 1])
axs[0, 1].set_title('Average Full Payment Rate by Balance Category')

sns.barplot(x='BALANCE_CATEGORY', y='CREDIT_LIMIT', data=grouped_data, ax=axs[1, 0])
axs[1, 0].set_title('Average Credit Limit by Balance Category')

sns.barplot(x='BALANCE_CATEGORY', y='PAYMENTS', data=grouped_data, ax=axs[1, 1])
axs[1, 1].set_title('Average Payments by Balance Category')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 32. Answering the second objective

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Analyzing distributions of One-off and Installment Purchases
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.histplot(data['ONEOFF_PURCHASES'], bins=30, ax=axs[0], kde=True, color='skyblue')
axs[0].set_title('Distribution of One-off Purchases')
axs[0].set_xlabel('One-off Purchases')
axs[0].set_ylabel('Frequency')

sns.histplot(data['INSTALLMENTS_PURCHASES'], bins=30, ax=axs[1], kde=True, color='lightgreen')
axs[1].set_title('Distribution of Installment Purchases')
axs[1].set_xlabel('Installment Purchases')
axs[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
data['INSTALLMENTS_PURCHASES'].describe(), data['ONEOFF_PURCHASES'].describe()
# Out:
# (count     8950.000000
#  mean       411.067645
#  std        904.338115
#  min          0.000000
#  25%          0.000000
#  50%         89.000000
#  75%        468.637500
#  max      22500.000000
#  Name: INSTALLMENTS_PURCHASES, dtype: float64,
#  count     8950.000000
#  mean       592.437371
#  std       1659.887917
#  min          0.000000
#  25%          0.000000
#  50%         38.000000
#  75%        577.405000
#  max      40761.250000
#  Name: ONEOFF_PURCHASES, dtype: float64)

# %% [markdown]
# After a thoughtful consideration and guesses,
# I set the following category:
#
# |ONEOFF_PURCHASES|SPENDING_TYPE|
# | :---: | :---: |
# | $\le$ 1| NONE |
# | $\le$ 100 | LOW |
# | $\le$ 750 | MODERATE |
# | $>$ 750 | HIGH |
#
# and
#
# |INSTALLMENT_PURCHASES|INSTALLMENT_TYPE|
# | :---: | :---: |
# | $\le$ 1| NONE |
# | $\le$ 100 | LOW |
# | $\le$ 600 | MODERATE |
# | $>$ 600 | HIGH |

# %%
import numpy as np

# Define custom bins based on the distribution observed from data['ONEOFF_PURCHASES'].describe() and similar for installments
oneoff_edges = [-np.inf, 1, 100, 750, np.inf]  # Assuming most values are 0, set the first bin edge between 0 and 1
installment_edges = [-np.inf, 1, 100, 600, np.inf]  # Adjust accordingly based on actual data

# Categorizing customers based on custom bins
data['SPENDING_TYPE'] = pd.cut(data['ONEOFF_PURCHASES'], bins=oneoff_edges, labels=['None', 'Low', 'Moderate', 'High'])
data['INSTALLMENT_TYPE'] = pd.cut(data['INSTALLMENTS_PURCHASES'], bins=installment_edges, labels=['None', 'Low', 'Moderate', 'High'])

# Viewing the new categorizations
print(data[['ONEOFF_PURCHASES', 'SPENDING_TYPE', 'INSTALLMENTS_PURCHASES', 'INSTALLMENT_TYPE']].head())
# Out:
#    ONEOFF_PURCHASES SPENDING_TYPE  INSTALLMENTS_PURCHASES INSTALLMENT_TYPE
# 0              0.00          None                    95.4              Low
# 1              0.00          None                     0.0             None
# 2            773.17          High                     0.0             None
# 3           1499.00          High                     0.0             None
# 4             16.00           Low                     0.0             None

# %%
data['UTILIZATION_RATIO'].describe()
# Out:
# count    8950.000000
# mean        0.388884
# std         0.389722
# min         0.000000
# 25%         0.041494
# 50%         0.302720
# 75%         0.717571
# max        15.909951
# Name: UTILIZATION_RATIO, dtype: float64

# %%
# Creating credit utilization ratio
data['UTILIZATION_RATIO'] = data['BALANCE'] / data['CREDIT_LIMIT']

# Segmenting by utilization
data['UTILIZATION_TYPE'] = pd.qcut(data['UTILIZATION_RATIO'], 4, labels=['Low', 'Moderate', 'High', 'Very High'])

# Plotting the distribution of Credit Utilization
plt.figure(figsize=(10, 6))
sns.histplot(data['UTILIZATION_RATIO'], bins=30, kde=True, color='purple')
plt.title('Distribution of Credit Utilization Ratios')
plt.xlabel('Credit Utilization Ratio')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Aggregate data by Spending and Utilization Type for visualization
segment_analysis = data.groupby(['SPENDING_TYPE', 'UTILIZATION_TYPE']).agg({
    'BALANCE': 'mean',
    'PAYMENTS': 'mean',
    'CREDIT_LIMIT': 'mean',
    'CUST_ID': 'count'
}).rename(columns={'CUST_ID': 'COUNT'}).reset_index()

# Visualizing customer segments
sns.catplot(x='UTILIZATION_TYPE', y='BALANCE', hue='SPENDING_TYPE', data=segment_analysis, kind='bar', height=5, aspect=2)
plt.title('Customer Segments by Spending and Utilization Type')
plt.ylabel('Average Balance')
plt.xlabel('Utilization Type')
plt.show()
# Out:
# /var/folders/jc/46_slfdn1kqdqvhq8h39xbk80000gn/T/ipykernel_37398/3229659651.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   segment_analysis = data.groupby(['SPENDING_TYPE', 'UTILIZATION_TYPE']).agg({

# %% [markdown]
# # 33. Answering the third objective
# For the third objectivbe, we will be focusing on the **Improving financial health**, therefore it is hoped that it can encourages the habits among customers.

# %%
# Analyzing the payment behavior
import matplotlib.pyplot as plt
import seaborn as sns

# Analyze the distribution of the percentage of full payment
plt.figure(figsize=(10, 6))
sns.histplot(data['PRC_FULL_PAYMENT'], bins=30, kde=False, color='green')
plt.title('Distribution of Full Payment Ratio')
plt.xlabel('Percentage of Full Payment')
plt.ylabel('Frequency')
plt.show()

# %%
# Analyzing credit utilization
# Analyze credit utilization
plt.figure(figsize=(10, 6))
sns.histplot(data['UTILIZATION_RATIO'], bins=30, kde=True, color='blue')
plt.title('Credit Utilization Ratios')
plt.xlabel('Utilization Ratio')
plt.ylabel('Number of Customers')
plt.show()

# %%
# Identifying patterns correlating to health financial behavior
# Correlation between full payment rates and other financial behaviors
financial_health_corr = data[['UTILIZATION_RATIO', 'PRC_FULL_PAYMENT', 'BALANCE', 'CREDIT_LIMIT']].corr()
sns.heatmap(financial_health_corr, annot=True, cmap='coolwarm')
plt.title('Correlation of Financial Health Indicators')
plt.show()

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                    0.000000                          0.083333  ...
# ...

# %%
# Assuming 'RISK_LEVEL' categorization exists
sns.catplot(x="RISK_LEVEL", y="PRC_FULL_PAYMENT", kind="bar", data=data)
plt.title("Average Full Payment by Risk Level")
plt.ylabel("Percentage of Full Payment")
plt.xlabel("Risk Level")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 2
#       1 # Assuming 'RISK_LEVEL' categorization exists
# ----> 2 sns.catplot(x="RISK_LEVEL", y="PRC_FULL_PAYMENT", kind="bar", data=data)
#       3 plt.title("Average Full Payment by Risk Level")
#       4 plt.ylabel("Percentage of Full Payment")
#
# File ~/miniconda3/envs/testbaru/lib/python3.10/site-packages/seaborn/categorical.py:2766, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2763     elif x is not None and y is not None:
#    2764         raise ValueError("Cannot pass values for both `x` and `y`.")
# -> 2766 p = Plotter(
#    2767     data=data,
# ...

# %%
data.to_csv('Latest Data - 2.csv')

# %%
data.columns
# Out:
# Index(['CUST_ID', 'BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
#        'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
#        'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY',
#        'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
#        'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
#        'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE',
#        'HIGH_RISK_CASH_ADVANCE', 'HIGH_RISK_BALANCE', 'BALANCE_CATEGORY',
#        'CREDIT_LIMIT_CATEGORY', 'RISK_SCORE', 'DELINQUENCY_STATUS',
#        'SPENDING_TYPE', 'INSTALLMENT_TYPE', 'UTILIZATION_RATIO',
#        'UTILIZATION_TYPE'],
#       dtype='object')

# %%
data[data['ONEOFF_PURCHASES'] == 0]
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40               0.0
# 1     C10002  3202.467416           0.909091       0.00               0.0
# 5     C10006  1809.828751           1.000000    1333.28               0.0
# 7     C10008  1823.652743           1.000000     436.20               0.0
# 10    C10011  1293.124939           1.000000     920.12               0.0
# ...      ...          ...                ...        ...               ...
# 8942  C19183    40.829749           1.000000     113.28               0.0
# 8945  C19186    28.493517           1.000000     291.12               0.0
# 8946  C19187    19.183215           1.000000     300.00               0.0
# 8947  C19188    23.398673           0.833333     144.40               0.0
# 8948  C19189    13.457564           0.833333       0.00               0.0
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...
